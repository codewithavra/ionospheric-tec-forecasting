# %% [markdown]
# ### Imports

# %%
import torch
import numpy as np
from src.preprocessing.sort_tec_data import build_sorted_dataset
from src.preprocessing.dataset import prepare_dataset
from src.configs.config import (
    BASE_DIR_1, OUTPUT_DIR_1, BASE_DIR_2, OUTPUT_DIR_2,
    F_L1, F_L2, F_L5, EVENT_THRESHOLD_PERCENTILE
)
from src.training.lstm_training import train_lstm
from src.training.transformer_training import train_transformer

from src.plots.loss_plots import (
    plot_lstm_loss, plot_transformer_loss,
)
from src.plots.prediction_plots import (
    plot_lstm_prediction, plot_transformer_prediction
)
from src.plots.delay_plots import (
    plot_diurnal_profile,
    plot_lstm_delay,
    plot_transformer_delay
)
from src.utils.iono_delay import delay_metrics, tec_to_iono_delay
from src.utils.save_results import save_delay_csv
from src.utils.metrics import (
    rmse,
    pearson_correlation,
    probability_of_detection,
    critical_success_index,
    f1_score,
    false_alarm_ratio,
)

# %% [markdown]
# ---
# # Dataset 1 — Day 41 Forecasting Workflow (18 June 2023)
# ---

# %% [markdown]
# ### 1. Base Directory and Output Setup — Dataset 1 (18 June 2023)

# %%
print(f"Base directory 1  : {BASE_DIR_1}")
print(f"Output directory 1: {OUTPUT_DIR_1}")
# Out:
# Base directory 1  : /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1
# Output directory 1: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet

# %% [markdown]
# ### 2. Creating Sorted TEC Dataset — Dataset 1
# ```text
# Process folders iisc1290_TECU to iisc1690_TECU and create one sorted CSV
# per folder containing the maximum TEC value for each minute.
# Returns: Number of output CSV files written.
# ```

# %%
written_files_1 = build_sorted_dataset(1)

print("TEC data sorting completed — Dataset 1.")
print(f"Number of output CSV files written: {written_files_1}")
print(f"Saved sorted CSV files to: {OUTPUT_DIR_1}")
# Out:
# TEC data sorting completed — Dataset 1.
# Number of output CSV files written: 41
# Saved sorted CSV files to: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet

# %% [markdown]
# #### QUICK SANITY CHECK — Dataset 1
# > Print first 6 lines of the first output file

# %%
sample_file = OUTPUT_DIR_1 / "iisc1290_TECU_sorted.csv"
if sample_file.exists():
    with sample_file.open("r", newline="", encoding="utf-8") as f:
        for i, line in enumerate(f):
            print(line.strip())
            if i >= 5:
                break
else:
    print(f"Sample file not found: {sample_file}")
# Out:
# Time(UTC),TEC(TECU)
# 09-05-23 00:00,42.390972
# 09-05-23 00:01,51.206161
# 09-05-23 00:02,32.852289
# 09-05-23 00:03,34.870453
# 09-05-23 00:04,39.373245

# %% [markdown]
# ### 3. Data Loading and Preprocessing — Dataset 1 (18 June 2023)
# ```text
# Loads sorted CSVs into a (days × minutes) numpy matrix,
# builds supervised input/target pairs, and
# normalises using training stats only.
# ```

# %%
X_train_1, y_train_1, X_val_1, y_val_1, stats_1, daily_matrix_1, daily_files_1 = prepare_dataset(1)

print(f"X_train : {X_train_1.shape}   y_train : {y_train_1.shape}")
print(f"X_val   : {X_val_1.shape}     y_val   : {y_val_1.shape}")
print(f"Norm stats : {stats_1}")
# Out:
# X_train : (29, 1440, 1)   y_train : (29, 1440, 1)
# X_val   : (11, 1440, 1)     y_val   : (11, 1440, 1)
# Norm stats : {'x_mean': 87.88667297363281, 'x_std': 45.894798288808595, 'y_mean': 86.92459106445312, 'y_std': 45.30130768822266}

# %% [markdown]
# ### 4. LSTM Training Workflow — Dataset 1: Day 41 Forecast (18 June 2023)
#
# > Dataset consists of 41 chronologically sorted TEC files.
#
# ```text
# Training Set
# ------------
# Input  : Days  1-29
# Target : Days  2-30
#
# Validation Set
# --------------
# Input  : Days 30-40
# Target : Days 31-41
#
# Forecast
# --------
# Input  : Day 40
# Output : Day 41
# ```

# %%
lstm_model_1, lstm_history_1 = train_lstm(X_train_1, y_train_1, X_val_1, y_val_1)
# Out:
# Epoch 1/50 — loss: 0.970071 — val_loss: 0.703141
# Epoch 2/50 — loss: 0.796376 — val_loss: 0.484105
# Epoch 3/50 — loss: 0.379775 — val_loss: 0.139985
# Epoch 4/50 — loss: 0.206873 — val_loss: 0.170383
# Epoch 5/50 — loss: 0.157360 — val_loss: 0.136358
# Epoch 6/50 — loss: 0.162006 — val_loss: 0.129844
# Epoch 7/50 — loss: 0.146071 — val_loss: 0.134694
# Epoch 8/50 — loss: 0.148146 — val_loss: 0.128769
# Epoch 9/50 — loss: 0.141884 — val_loss: 0.126743
# Epoch 10/50 — loss: 0.142981 — val_loss: 0.124715
# Epoch 11/50 — loss: 0.134841 — val_loss: 0.125377
# Epoch 12/50 — loss: 0.138120 — val_loss: 0.117390
# Epoch 13/50 — loss: 0.129662 — val_loss: 0.117523
# Epoch 14/50 — loss: 0.130526 — val_loss: 0.114831
# Epoch 15/50 — loss: 0.134959 — val_loss: 0.116569
# Epoch 16/50 — loss: 0.126524 — val_loss: 0.116000
# Epoch 17/50 — loss: 0.135709 — val_loss: 0.118328
# Epoch 18/50 — loss: 0.125984 — val_loss: 0.119945
# Epoch 19/50 — loss: 0.124353 — val_loss: 0.115734
# ...

# %% [markdown]
# ### 5. LSTM Loss and Validation Curve — Dataset 1

# %%
plot_lstm_loss(lstm_history_1, dataset_label="dataset1", output_dir=str(OUTPUT_DIR_1 / "plots"))
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet/plots/loss_lstm_dataset1_2026-07-17.png
# Final train loss : 0.126803
# Final val   loss : 0.113233

# %% [markdown]
# ### 6. LSTM Forecast for Day 41 — 18 June 2023 (Dataset 1)

# %%
x_mean_1, x_std_1 = stats_1["x_mean"], stats_1["x_std"]
y_mean_1, y_std_1 = stats_1["y_mean"], stats_1["y_std"]

day40_raw_1 = daily_matrix_1[39]
actual41_1  = daily_matrix_1[40]

day40_in_1 = ((day40_raw_1 - x_mean_1) / x_std_1)[np.newaxis, ..., np.newaxis]   # (1, 1440, 1)

device = next(lstm_model_1.parameters()).device
src    = torch.tensor(day40_in_1, dtype=torch.float32).to(device)

lstm_model_1.eval()
with torch.no_grad():
    pred41_norm_1 = lstm_model_1(src).squeeze().cpu().numpy()   # (1440,)

lstm_pred41_1 = pred41_norm_1 * y_std_1 + y_mean_1

lstm_rmse_1, lstm_mae_1 = plot_lstm_prediction(
    actual41_1, lstm_pred41_1,
    target_day=41, dataset_label="dataset1",
    output_dir=str(OUTPUT_DIR_1 / "plots"),
)
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet/plots/prediction_lstm_day41_dataset1_2026-07-17.png
# LSTM Day-41 RMSE : 15.3465 TECU
# LSTM Day-41 MAE  : 11.0779 TECU

# %% [markdown]
# ### 7. Transformer Training Workflow for Dataset 1

# %%
transformer_model_1, transformer_history_1 = train_transformer(X_train_1, y_train_1, X_val_1, y_val_1)
# Out:
# [Transformer] Training on: cpu
# TECTransformerEncoder(
#   (input_proj): Linear(in_features=1, out_features=64, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (linear1): Linear(in_features=64, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=128, out_features=64, bias=True)
#         (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True, bias=True)
#         (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True, bias=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True, bias=True)
# ...

# %% [markdown]
# ### 8. Transformer Loss and Validation Curve — Dataset 1

# %%
plot_transformer_loss(transformer_history_1, dataset_label="dataset1", output_dir=str(OUTPUT_DIR_1 / "plots"))
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet/plots/loss_transformer_dataset1_2026-07-17.png
# Final train loss : 0.195501
# Final val   loss : 0.113853

# %% [markdown]
# ### 9. Transformer Forecast for Day 41 — 18 June 2023 (Dataset 1)

# %%
day40_in_t_1 = ((day40_raw_1 - x_mean_1) / x_std_1)[np.newaxis, ..., np.newaxis]   # (1, 1440, 1)

device  = next(transformer_model_1.parameters()).device
src_t_1 = torch.tensor(day40_in_t_1, dtype=torch.float32).to(device)

transformer_model_1.eval()
with torch.no_grad():
    trans_pred41_norm_1 = transformer_model_1(src_t_1).squeeze().cpu().numpy()   # (1440,)

trans_pred41_1 = trans_pred41_norm_1 * y_std_1 + y_mean_1

trans_rmse_1, trans_mae_1 = plot_transformer_prediction(
    actual41_1, trans_pred41_1,
    target_day=41, dataset_label="dataset1",
    output_dir=str(OUTPUT_DIR_1 / "plots"),
)
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet/plots/prediction_transformer_day41_dataset1_2026-07-17.png
# Transformer Day-41 RMSE : 14.8659 TECU
# Transformer Day-41 MAE  : 10.9083 TECU

# %% [markdown]
# ### 10. Model Comparison Summary for Day 41 Forecast — 18 June 2023 (Dataset 1)

# %%
print("=" * 45)
print(f"{'Model':<15} {'RMSE (TECU)':>12} {'MAE (TECU)':>12}")
print("-" * 45)
print(f"{'LSTM':<15} {lstm_rmse_1:>12.4f} {lstm_mae_1:>12.4f}")
print(f"{'Transformer':<15} {trans_rmse_1:>12.4f} {trans_mae_1:>12.4f}")
print("=" * 45)
# Out:
# ...
# Model            RMSE (TECU)   MAE (TECU)
# ---------------------------------------------
# LSTM                 15.3465      11.0779
# Transformer          14.8659      10.9083
# ...

# %% [markdown]
# ### 11. Ionospheric Delay Analysis for LSTM Forecast — 18 June 2023 (Dataset 1)
# ```text
# F_L1 = 1575.42e6 Hz
# F_L2 = 1227.60e6 Hz
# F_L5 = 1176.45e6 Hz
# ```

# %%
plot_lstm_delay(actual41_1, lstm_pred41_1, freq=F_L1, target_day=41, dataset_label="dataset1", output_dir=str(OUTPUT_DIR_1 / "plots"))
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet/plots/delay_lstm_L1_day41_dataset1_2026-07-17.png
# LSTM 1575420000.0 — RMSE: 2.49234 m   MAE: 1.79910 m

# %%
plot_lstm_delay(actual41_1, lstm_pred41_1, freq=F_L2, target_day=41, dataset_label="dataset1", output_dir=str(OUTPUT_DIR_1 / "plots"))
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet/plots/delay_lstm_L2_day41_dataset1_2026-07-17.png
# LSTM 1227600000.0 — RMSE: 4.10474 m   MAE: 2.96302 m

# %%
plot_lstm_delay(actual41_1, lstm_pred41_1, freq=F_L5, target_day=41, dataset_label="dataset1", output_dir=str(OUTPUT_DIR_1 / "plots"))
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet/plots/delay_lstm_L5_day41_dataset1_2026-07-17.png
# LSTM 1176450000.0 — RMSE: 4.46943 m   MAE: 3.22628 m

# %% [markdown]
# ### 12. Ionospheric Delay Analysis for Transformer Forecast — 18 June 2023 (Dataset 1)
# ```text
# F_L1 = 1575.42e6 Hz
# F_L2 = 1227.60e6 Hz
# F_L5 = 1176.45e6 Hz
# ```

# %%
plot_transformer_delay(actual41_1, trans_pred41_1, freq=F_L1, target_day=41, dataset_label="dataset1", output_dir=str(OUTPUT_DIR_1 / "plots"))
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet/plots/delay_transformer_L1_day41_dataset1_2026-07-17.png
# Transformer 1575420000.0 — RMSE: 2.41429 m   MAE: 1.77157 m

# %%
plot_transformer_delay(actual41_1, trans_pred41_1, freq=F_L2, target_day=41, dataset_label="dataset1", output_dir=str(OUTPUT_DIR_1 / "plots"))
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet/plots/delay_transformer_L2_day41_dataset1_2026-07-17.png
# Transformer 1227600000.0 — RMSE: 3.97621 m   MAE: 2.91767 m

# %%
plot_transformer_delay(actual41_1, trans_pred41_1, freq=F_L5, target_day=41, dataset_label="dataset1", output_dir=str(OUTPUT_DIR_1 / "plots"))
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet/plots/delay_transformer_L5_day41_dataset1_2026-07-17.png
# Transformer 1176450000.0 — RMSE: 4.32948 m   MAE: 3.17690 m

# %% [markdown]
# ### 13. Diurnal Hourly TEC Profile — 18 June 2023 (Dataset 1)

# %%
plot_diurnal_profile(actual41_1, lstm_pred41_1, trans_pred41_1, frequency=F_L1, target_day=41, dataset_label="dataset1", output_dir=str(OUTPUT_DIR_1 / "plots"))
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet/plots/diurnal_L1_day41_dataset1_2026-07-17.png

# %% [markdown]
# ### 14. Delay Error Metrics for Day 41 Forecast — 18 June 2023 (Dataset 1)

# %%
iono_actual41_1 = tec_to_iono_delay(actual41_1)
iono_lstm41_1   = tec_to_iono_delay(lstm_pred41_1)
iono_trans41_1  = tec_to_iono_delay(trans_pred41_1)

print("Ionospheric Delay Error (L1, vertical) — Day 41 — Dataset 1")
print("=" * 62)
delay_metrics("LSTM",        iono_lstm41_1,  iono_actual41_1)
delay_metrics("Transformer", iono_trans41_1, iono_actual41_1)
# Out:
# Ionospheric Delay Error (L1, vertical) — Day 41 — Dataset 1
# ...
# LSTM             RMSE = 2.49234 m   MAE = 1.79910 m   Bias = -0.11491 m
# Transformer      RMSE = 2.41429 m   MAE = 1.77157 m   Bias = -0.07010 m
# {'name': 'Transformer',
#  'rmse': 2.4142940044403076,
#  'mae': 1.7715654373168945,
#  'bias': -0.07009633630514145}

# %% [markdown]
# ### 15. Save Forecast Output CSV — 18 June 2023 (Dataset 1)

# %%
save_delay_csv(actual41_1, lstm_pred41_1, trans_pred41_1, output_dir=OUTPUT_DIR_1)
# Out:
# Delay table saved → /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet1/sortedDataSet/day41_ionospheric_delay.csv

# %% [markdown]
# ---
# # Dataset 2 — Day 40/41 Forecasting Workflow
# ---

# %% [markdown]
# ### 16. Base Directory and Output Setup — Dataset 2

# %%
print(f"Base directory 2  : {BASE_DIR_2}")
print(f"Output directory 2: {OUTPUT_DIR_2}")
# Out:
# Base directory 2  : /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet2
# Output directory 2: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet2/sortedDataSet

# %% [markdown]
# ### 17. Creating Sorted TEC Dataset — Dataset 2
# ```text
# Process folders iisc0910_TECU to iisc1310_TECU and create one sorted CSV
# per folder containing the maximum TEC value for each minute.
# Returns: Number of output CSV files written.
# ```

# %%
written_files_2 = build_sorted_dataset(2)

print("TEC data sorting completed — Dataset 2.")
print(f"Number of output CSV files written: {written_files_2}")
print(f"Saved sorted CSV files to: {OUTPUT_DIR_2}")
# Out:
# TEC data sorting completed — Dataset 2.
# Number of output CSV files written: 41
# Saved sorted CSV files to: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet2/sortedDataSet

# %% [markdown]
# #### QUICK SANITY CHECK — Dataset 2
# > Print first 6 lines of the first output file

# %%
sample_file_2 = OUTPUT_DIR_2 / "iisc0910_TECU_sorted.csv"
if sample_file_2.exists():
    with sample_file_2.open("r", newline="", encoding="utf-8") as f:
        for i, line in enumerate(f):
            print(line.strip())
            if i >= 5:
                break
else:
    print(f"Sample file not found: {sample_file_2}")
# Out:
# Time(UTC),TEC(TECU)
# 31-03-24 00:00,36.907657
# 31-03-24 00:01,38.230887
# 31-03-24 00:02,30.567575
# 31-03-24 00:03,31.386264
# 31-03-24 00:04,34.860934

# %% [markdown]
# ### 18. Data Loading and Preprocessing — Dataset 2
# ```text
# Loads sorted CSVs into a (days × minutes) numpy matrix,
# builds supervised input/target pairs, and
# normalises using training stats only.
# ```

# %%
X_train_2, y_train_2, X_val_2, y_val_2, stats_2, daily_matrix_2, daily_files_2 = prepare_dataset(2)

print(f"X_train : {X_train_2.shape}   y_train : {y_train_2.shape}")
print(f"X_val   : {X_val_2.shape}     y_val   : {y_val_2.shape}")
print(f"Norm stats : {stats_2}")
# Out:
# X_train : (29, 1440, 1)   y_train : (29, 1440, 1)
# X_val   : (11, 1440, 1)     y_val   : (11, 1440, 1)
# Norm stats : {'x_mean': 128.01817321777344, 'x_std': 59.78969956444336, 'y_mean': 128.05174255371094, 'y_std': 59.79975129173828}

# %% [markdown]
# ### 19. LSTM Training Workflow — Dataset 2: Day 40 to Day 41 Forecast
# > Dataset consists of 41 chronologically sorted TEC files.
#
# ```text
# Training Set
# ------------
# Input  : Days  1-29
# Target : Days  2-30
#
# Validation Set
# --------------
# Input  : Days 30-40
# Target : Days 31-41
#
# Forecast
# --------
# Input  : Day 39  →  Output : Day 40  (9 May 2024)
# Input  : Day 40  →  Output : Day 41  (10 May 2024)
# ```

# %%
lstm_model_2, lstm_history_2 = train_lstm(X_train_2, y_train_2, X_val_2, y_val_2)
# Out:
# Epoch 1/50 — loss: 0.918997 — val_loss: 0.775285
# Epoch 2/50 — loss: 0.763260 — val_loss: 0.546499
# Epoch 3/50 — loss: 0.410011 — val_loss: 0.171813
# Epoch 4/50 — loss: 0.250298 — val_loss: 0.197389
# Epoch 5/50 — loss: 0.204431 — val_loss: 0.181901
# Epoch 6/50 — loss: 0.189057 — val_loss: 0.168143
# Epoch 7/50 — loss: 0.166629 — val_loss: 0.162503
# Epoch 8/50 — loss: 0.156843 — val_loss: 0.155640
# Epoch 9/50 — loss: 0.151543 — val_loss: 0.152629
# Epoch 10/50 — loss: 0.148758 — val_loss: 0.151806
# Epoch 11/50 — loss: 0.149446 — val_loss: 0.149968
# Epoch 12/50 — loss: 0.144828 — val_loss: 0.154328
# Epoch 13/50 — loss: 0.143949 — val_loss: 0.150096
# Epoch 14/50 — loss: 0.146662 — val_loss: 0.153165
# Epoch 15/50 — loss: 0.146448 — val_loss: 0.150410
# Epoch 16/50 — loss: 0.145690 — val_loss: 0.151395
# Epoch 17/50 — loss: 0.141061 — val_loss: 0.150866
# Epoch 18/50 — loss: 0.141965 — val_loss: 0.150268
# Epoch 19/50 — loss: 0.144823 — val_loss: 0.153367
# ...

# %% [markdown]
# ### 20. LSTM Loss and Validation Curve — Dataset 2

# %%
plot_lstm_loss(lstm_history_2, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet2/sortedDataSet/plots/loss_lstm_dataset2_2026-07-17.png
# Final train loss : 0.138561
# Final val   loss : 0.148053

# %% [markdown]
# ### 21a. LSTM Forecast for Day 40 — 17 June 2023 (Dataset 2)

# %%
x_mean_2, x_std_2 = stats_2["x_mean"], stats_2["x_std"]
y_mean_2, y_std_2 = stats_2["y_mean"], stats_2["y_std"]

day39_raw_2 = daily_matrix_2[38]
actual40_2  = daily_matrix_2[39]

day39_in_2 = ((day39_raw_2 - x_mean_2) / x_std_2)[np.newaxis, ..., np.newaxis]   # (1, 1440, 1)

device = next(lstm_model_2.parameters()).device
src39  = torch.tensor(day39_in_2, dtype=torch.float32).to(device)

lstm_model_2.eval()
with torch.no_grad():
    pred40_norm_2 = lstm_model_2(src39).squeeze().cpu().numpy()   # (1440,)

lstm_pred40_2 = pred40_norm_2 * y_std_2 + y_mean_2

# derive label automatically from the loaded files
label_40_2 = f"Actual Day 40 ({daily_files_2[-2].stem.replace('_sorted', '')})"  # -> "Actual Day 40 (iisc1300_TECU)"

lstm_rmse_40_2, lstm_mae_40_2 = plot_lstm_prediction(
    actual40_2, lstm_pred40_2,
    actual_label=label_40_2, target_day=40, dataset_label="dataset2",
    output_dir=str(OUTPUT_DIR_2 / "plots"),
)
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet2/sortedDataSet/plots/prediction_lstm_day40_dataset2_2026-07-17.png
# LSTM Day-40 RMSE : 20.8786 TECU
# LSTM Day-40 MAE  : 14.8954 TECU

# %% [markdown]
# ### 21b. LSTM Forecast for Day 41 — 10 May 2024 (Dataset 2)

# %%
day40_raw_2 = daily_matrix_2[39]
actual41_2  = daily_matrix_2[40]

day40_in_2 = ((day40_raw_2 - x_mean_2) / x_std_2)[np.newaxis, ..., np.newaxis]   # (1, 1440, 1)

device = next(lstm_model_2.parameters()).device
src    = torch.tensor(day40_in_2, dtype=torch.float32).to(device)

lstm_model_2.eval()
with torch.no_grad():
    pred41_norm_2 = lstm_model_2(src).squeeze().cpu().numpy()   # (1440,)

lstm_pred41_2 = pred41_norm_2 * y_std_2 + y_mean_2

# derive label automatically from the loaded files
label_2 = f"Actual Day 41 ({daily_files_2[-1].stem.replace('_sorted', '')})"  # -> "Actual Day 41 (iisc1310_TECU)"

lstm_rmse_2, lstm_mae_2 = plot_lstm_prediction(
    actual41_2, lstm_pred41_2,
    actual_label=label_2, target_day=41, dataset_label="dataset2",
    output_dir=str(OUTPUT_DIR_2 / "plots"),
)
# Out:
# Saved: /home/anirban-roy/Desktop/IonoWork/ionospheric-tec-forecasting/DataSet/DataSet2/sortedDataSet/plots/prediction_lstm_day41_dataset2_2026-07-17.png
# LSTM Day-41 RMSE : 21.7137 TECU
# LSTM Day-41 MAE  : 16.7166 TECU

# %% [markdown]
# ### 22. Transformer Training Workflow for Dataset 2 — Day 40 to Day 41 Forecast (9–10 May 2024)

# %%
transformer_model_2, transformer_history_2 = train_transformer(X_train_2, y_train_2, X_val_2, y_val_2)
# Out:
# [Transformer] Training on: cpu
# TECTransformerEncoder(
#   (input_proj): Linear(in_features=1, out_features=64, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (linear1): Linear(in_features=64, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=128, out_features=64, bias=True)
#         (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True, bias=True)
#         (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True, bias=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True, bias=True)
# ...

# %% [markdown]
# ### 23. Transformer Loss and Validation Curve — Dataset 2 (9–10 May 2024)

# %%
plot_transformer_loss(transformer_history_2, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %% [markdown]
# ### 24a. Transformer Forecast for Day 40 — 9th May 2024 (Dataset 2)

# %%
day39_in_t_2 = ((day39_raw_2 - x_mean_2) / x_std_2)[np.newaxis, ..., np.newaxis]   # (1, 1440, 1)

device   = next(transformer_model_2.parameters()).device
src39_t  = torch.tensor(day39_in_t_2, dtype=torch.float32).to(device)

transformer_model_2.eval()
with torch.no_grad():
    trans_pred40_norm_2 = transformer_model_2(src39_t).squeeze().cpu().numpy()   # (1440,)

trans_pred40_2 = trans_pred40_norm_2 * y_std_2 + y_mean_2
trans_rmse_40_2, trans_mae_40_2 = plot_transformer_prediction(
    actual40_2, trans_pred40_2,
    actual_label=label_40_2, target_day=40, dataset_label="dataset2",
    output_dir=str(OUTPUT_DIR_2 / "plots"),
)

# %% [markdown]
# ### 24b. Transformer Forecast for Day 41 — 10 May 2024 (Dataset 2)

# %%
day40_in_t_2 = ((day40_raw_2 - x_mean_2) / x_std_2)[np.newaxis, ..., np.newaxis]   # (1, 1440, 1)

device  = next(transformer_model_2.parameters()).device
src_t_2 = torch.tensor(day40_in_t_2, dtype=torch.float32).to(device)

transformer_model_2.eval()
with torch.no_grad():
    trans_pred41_norm_2 = transformer_model_2(src_t_2).squeeze().cpu().numpy()   # (1440,)

trans_pred41_2 = trans_pred41_norm_2 * y_std_2 + y_mean_2
trans_rmse_2, trans_mae_2 = plot_transformer_prediction(
    actual41_2, trans_pred41_2,
    actual_label=label_2, target_day=41, dataset_label="dataset2",
    output_dir=str(OUTPUT_DIR_2 / "plots"),
)

# %% [markdown]
# ### 25. Model Comparison Summary for Day 40/41 Forecast — 9–10 May 2024 (Dataset 2)

# %%
print("=" * 60)
print(f"{'Model':<15} {'Target Day':<12} {'RMSE (TECU)':>12} {'MAE (TECU)':>12}")
print("-" * 60)
print(f"{'LSTM':<15} {'Day 40':<12} {lstm_rmse_40_2:>12.4f} {lstm_mae_40_2:>12.4f}")
print(f"{'Transformer':<15} {'Day 40':<12} {trans_rmse_40_2:>12.4f} {trans_mae_40_2:>12.4f}")
print("-" * 60)
print(f"{'LSTM':<15} {'Day 41':<12} {lstm_rmse_2:>12.4f} {lstm_mae_2:>12.4f}")
print(f"{'Transformer':<15} {'Day 41':<12} {trans_rmse_2:>12.4f} {trans_mae_2:>12.4f}")
print("=" * 60)

# %% [markdown]
# ### 26a. Ionospheric Delay Analysis for LSTM Forecast — Day 40 (9 May 2024, Dataset 2)
# ```text
# F_L1 = 1575.42e6 Hz
# F_L2 = 1227.60e6 Hz
# F_L5 = 1176.45e6 Hz
# ```

# %%
plot_lstm_delay(actual40_2, lstm_pred40_2, freq=F_L1, target_day=40, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %%
plot_lstm_delay(actual40_2, lstm_pred40_2, freq=F_L2, target_day=40, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %%
plot_lstm_delay(actual40_2, lstm_pred40_2, freq=F_L5, target_day=40, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %% [markdown]
# ### 26b. Ionospheric Delay Analysis for Transformer Forecast — Day 40 (9 May 2024, Dataset 2)
# ```text
# F_L1 = 1575.42e6 Hz
# F_L2 = 1227.60e6 Hz
# F_L5 = 1176.45e6 Hz
# ```

# %%
plot_transformer_delay(actual40_2, trans_pred40_2, freq=F_L1, target_day=40, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %%
plot_transformer_delay(actual40_2, trans_pred40_2, freq=F_L2, target_day=40, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %%
plot_transformer_delay(actual40_2, trans_pred40_2, freq=F_L5, target_day=40, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %% [markdown]
# ### 27a. Ionospheric Delay Analysis for LSTM Forecast — Day 41 (10 May 2024, Dataset 2)
# ```text
# F_L1 = 1575.42e6 Hz
# F_L2 = 1227.60e6 Hz
# F_L5 = 1176.45e6 Hz
# ```

# %%
plot_lstm_delay(actual41_2, lstm_pred41_2, freq=F_L1, target_day=41, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %%
plot_lstm_delay(actual41_2, lstm_pred41_2, freq=F_L2, target_day=41, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %%
plot_lstm_delay(actual41_2, lstm_pred41_2, freq=F_L5, target_day=41, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %% [markdown]
# ### 27b. Ionospheric Delay Analysis for Transformer Forecast — Day 41 (10 May 2024, Dataset 2)
# ```text
# F_L1 = 1575.42e6 Hz
# F_L2 = 1227.60e6 Hz
# F_L5 = 1176.45e6 Hz
# ```

# %%
plot_transformer_delay(actual41_2, trans_pred41_2, freq=F_L1, target_day=41, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %%
plot_transformer_delay(actual41_2, trans_pred41_2, freq=F_L2, target_day=41, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %%
plot_transformer_delay(actual41_2, trans_pred41_2, freq=F_L5, target_day=41, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %% [markdown]
# ### 28a. Diurnal Hourly TEC Profile — Day 40 (9 May 2024, Dataset 2)

# %%
plot_diurnal_profile(actual40_2, lstm_pred40_2, trans_pred40_2, frequency=F_L1, target_day=40, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %% [markdown]
# ### 28b. Diurnal Hourly TEC Profile — Day 41 (10 May 2024, Dataset 2)

# %%
plot_diurnal_profile(actual41_2, lstm_pred41_2, trans_pred41_2, frequency=F_L1, target_day=41, dataset_label="dataset2", output_dir=str(OUTPUT_DIR_2 / "plots"))

# %% [markdown]
# ### 29. Delay Error Metrics for Day 40/41 Forecast — 9–10 May 2024 (Dataset 2)

# %%
iono_actual41_2 = tec_to_iono_delay(actual41_2)
iono_lstm41_2   = tec_to_iono_delay(lstm_pred41_2)
iono_trans41_2  = tec_to_iono_delay(trans_pred41_2)

iono_actual40_2 = tec_to_iono_delay(actual40_2)
iono_lstm40_2   = tec_to_iono_delay(lstm_pred40_2)
iono_trans40_2  = tec_to_iono_delay(trans_pred40_2)

print("Ionospheric Delay Error (L1, vertical) — Day 40 — Dataset 2")
print("=" * 62)
delay_metrics("LSTM",        iono_lstm40_2,  iono_actual40_2)
delay_metrics("Transformer", iono_trans40_2, iono_actual40_2)

print()
print("Ionospheric Delay Error (L1, vertical) — Day 41 — Dataset 2")
print("=" * 62)
delay_metrics("LSTM",        iono_lstm41_2,  iono_actual41_2)
delay_metrics("Transformer", iono_trans41_2, iono_actual41_2)

# %% [markdown]
# ### 30a. Save Forecast Output CSV — Day 40 (9 May 2024, Dataset 2)

# %%
save_delay_csv(actual40_2, lstm_pred40_2, trans_pred40_2, output_dir=OUTPUT_DIR_2, filename="day40_ionospheric_delay.csv")

# %% [markdown]
# ### 30b. Save Forecast Output CSV — Day 41 (10 May 2024, Dataset 2)

# %%
save_delay_csv(actual41_2, lstm_pred41_2, trans_pred41_2, output_dir=OUTPUT_DIR_2, filename="day41_ionospheric_delay.csv")

# %%
training_targets = daily_matrix_1[1:30]
storm_threshold = float(
    np.percentile(training_targets, EVENT_THRESHOLD_PERCENTILE)
)

print(
    f"High-TEC threshold ({EVENT_THRESHOLD_PERCENTILE:.0f}th percentile): "
    f"{storm_threshold:.2f} TECU"
)

# %%
lstm_rmse_metric_1 = rmse(lstm_pred41_1, actual41_1)
transformer_rmse_metric_1 = rmse(trans_pred41_1, actual41_1)

print(f"LSTM RMSE:        {lstm_rmse_metric_1:.4f} TECU")
print(f"Transformer RMSE: {transformer_rmse_metric_1:.4f} TECU")

# %%
lstm_rmse_metric_2 = rmse(lstm_pred41_2, actual41_2)
transformer_rmse_metric_2 = rmse(trans_pred41_2, actual41_2)

print(f"LSTM RMSE:        {lstm_rmse_metric_2:.4f} TECU")
print(f"Transformer RMSE: {transformer_rmse_metric_2:.4f} TECU")

# %%
lstm_correlation_1 = pearson_correlation(lstm_pred41_1, actual41_1)
transformer_correlation_1 = pearson_correlation(trans_pred41_1, actual41_1)

print("Dataset 1 — Day 41")
print(f"LSTM correlation:        {lstm_correlation_1:.4f}")
print(f"Transformer correlation: {transformer_correlation_1:.4f}")

# %%
lstm_correlation_2 = pearson_correlation(lstm_pred41_2, actual41_2)
transformer_correlation_2 = pearson_correlation(trans_pred41_2, actual41_2)

print("Dataset 2 — Day 41")
print(f"LSTM correlation:        {lstm_correlation_2:.4f}")
print(f"Transformer correlation: {transformer_correlation_2:.4f}")

# %%
storm_threshold_1 = float(
    np.percentile(daily_matrix_1[1:30], EVENT_THRESHOLD_PERCENTILE)
)

storm_threshold_2 = float(
    np.percentile(daily_matrix_2[1:30], EVENT_THRESHOLD_PERCENTILE)
)

print(f"Dataset 1 threshold: {storm_threshold_1:.2f} TECU")
print(f"Dataset 2 threshold: {storm_threshold_2:.2f} TECU")

# %%
lstm_pod_1 = probability_of_detection(
    lstm_pred41_1, actual41_1, threshold=storm_threshold_1
)
transformer_pod_1 = probability_of_detection(
    trans_pred41_1, actual41_1, threshold=storm_threshold_1
)

print("Dataset 1 — Day 41 POD")
print(f"LSTM POD:        {lstm_pod_1:.4f}")
print(f"Transformer POD: {transformer_pod_1:.4f}")

# %%
lstm_pod_2 = probability_of_detection(
    lstm_pred41_2, actual41_2, threshold=storm_threshold_2
)
transformer_pod_2 = probability_of_detection(
    trans_pred41_2, actual41_2, threshold=storm_threshold_2
)

print("Dataset 2 — Day 41 POD")
print(f"LSTM POD:        {lstm_pod_2:.4f}")
print(f"Transformer POD: {transformer_pod_2:.4f}")

# %%
lstm_csi_1 = critical_success_index(
    lstm_pred41_1, actual41_1, threshold=storm_threshold_1
)
transformer_csi_1 = critical_success_index(
    trans_pred41_1, actual41_1, threshold=storm_threshold_1
)

print("Dataset 1 — Day 41 CSI")
print(f"LSTM CSI:        {lstm_csi_1:.4f}")
print(f"Transformer CSI: {transformer_csi_1:.4f}")

# %%
lstm_csi_2 = critical_success_index(
    lstm_pred41_2, actual41_2, threshold=storm_threshold_2
)
transformer_csi_2 = critical_success_index(
    trans_pred41_2, actual41_2, threshold=storm_threshold_2
)

print("Dataset 2 — Day 41 CSI")
print(f"LSTM CSI:        {lstm_csi_2:.4f}")
print(f"Transformer CSI: {transformer_csi_2:.4f}")

# %%
lstm_f1_1 = f1_score(
    lstm_pred41_1, actual41_1, threshold=storm_threshold_1
)
transformer_f1_1 = f1_score(
    trans_pred41_1, actual41_1, threshold=storm_threshold_1
)

print("Dataset 1 — Day 41 F1 score")
print(f"LSTM F1:        {lstm_f1_1:.4f}")
print(f"Transformer F1: {transformer_f1_1:.4f}")

# %%
lstm_f1_2 = f1_score(
    lstm_pred41_2, actual41_2, threshold=storm_threshold_2
)
transformer_f1_2 = f1_score(
    trans_pred41_2, actual41_2, threshold=storm_threshold_2
)

print("Dataset 2 — Day 41 F1 score")
print(f"LSTM F1:        {lstm_f1_2:.4f}")
print(f"Transformer F1: {transformer_f1_2:.4f}")

# %%
lstm_far_1 = false_alarm_ratio(
    lstm_pred41_1, actual41_1, threshold=storm_threshold_1
)
transformer_far_1 = false_alarm_ratio(
    trans_pred41_1, actual41_1, threshold=storm_threshold_1
)

print("Dataset 1 — Day 41 FAR")
print(f"LSTM FAR:        {lstm_far_1:.4f}")
print(f"Transformer FAR: {transformer_far_1:.4f}")

# %%
lstm_far_2 = false_alarm_ratio(
    lstm_pred41_2, actual41_2, threshold=storm_threshold_2
)
transformer_far_2 = false_alarm_ratio(
    trans_pred41_2, actual41_2, threshold=storm_threshold_2
)

print("Dataset 2 — Day 41 FAR")
print(f"LSTM FAR:        {lstm_far_2:.4f}")
print(f"Transformer FAR: {transformer_far_2:.4f}")

# %%
def print_event_counts(name, actual, lstm_pred, trans_pred, threshold):
    print(f"\n{name}")
    print(f"Threshold: {threshold:.2f} TECU")
    print(f"Actual events:       {np.sum(actual >= threshold)}")
    print(f"LSTM predicted:      {np.sum(lstm_pred >= threshold)}")
    print(f"Transformer predicted: {np.sum(trans_pred >= threshold)}")

print_event_counts(
    "Dataset 1 — Day 41",
    actual41_1, lstm_pred41_1, trans_pred41_1, storm_threshold_1,
)

print_event_counts(
    "Dataset 2 — Day 41",
    actual41_2, lstm_pred41_2, trans_pred41_2, storm_threshold_2,
)
